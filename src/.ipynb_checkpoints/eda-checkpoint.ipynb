# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("../data/PostTypeAnalysisDateset.csv")
df.head()
# Out:
#         post_date                         entity_id  followers  is_picture  \
# 0    1/2/20 17:10  7AD030340F434EECA5B4FC28034E1113   242458.0       False
# 1    1/2/20 17:46  7AD030340F434EECA5B4FC28034E1113   242458.0       False
# 2   10/9/20 16:06  4AAFEFB838974FDCA41932C4D32FD52A  2102820.0       False
# 3   10/9/20 16:08  4AAFEFB838974FDCA41932C4D32FD52A  2102820.0       False
# 4  10/10/20 13:00  4A3372EBDC9C484AA8503A96CD14B858  1023570.0       False
#
#    is_video  video_duration_secs   impressions  likes  shares  replies  \
# 0     False                  NaN   36023.36585    123       3       42
# 1     False                  NaN   23402.68323      4       0        0
# 2     False                  NaN  204639.92030     24       1        2
# 3     False                  NaN  208872.73630     91       1        2
# 4     False                  NaN  136020.57130    465       9        2
#
#    engagement_rate
# 0         0.000693
# 1         0.000017
# 2         0.000013
# 3         0.000045
# 4         0.000465

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15141 entries, 0 to 15140
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   post_date            15141 non-null  object
#  1   entity_id            15141 non-null  object
#  2   followers            15127 non-null  float64
#  3   is_picture           15141 non-null  bool
#  4   is_video             15141 non-null  bool
#  5   video_duration_secs  1989 non-null   float64
#  6   impressions          15127 non-null  float64
#  7   likes                15141 non-null  int64
#  8   shares               15141 non-null  int64
#  9   replies              15141 non-null  int64
#  10  engagement_rate      15141 non-null  float64
# dtypes: bool(2), float64(4), int64(3), object(2)
# memory usage: 975.9+ KB

# %%
df.isnull().sum()
# Out:
# post_date                  0
# entity_id                  0
# followers                 14
# is_picture                 0
# is_video                   0
# video_duration_secs    13152
# impressions               14
# likes                      0
# shares                     0
# replies                    0
# engagement_rate            0
# dtype: int64

# %%
df[df.followers.isnull()]
# Out:
#            post_date                         entity_id  followers  is_picture  \
# 287    9/16/20 12:05  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 3940   9/16/20 14:00  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 3943   9/16/20 17:59  4AAFEFB838974FDCA41932C4D32FD52A        NaN        True
# 3944   9/16/20 17:59  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 3945   9/16/20 20:52  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 3946   9/16/20 20:55  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 3947   9/16/20 21:28  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 4018   9/16/20 18:34  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 4336     8/8/20 2:41  4AAFEFB838974FDCA41932C4D32FD52A        NaN       False
# 7822   7/27/20 16:56  4AAFEFB838974FDCA41932C4D32FD52A        NaN        True
# 9040   9/15/20 16:01  4A3372EBDC9C484AA8503A96CD14B858        NaN        True
# 9068   9/15/20 16:01  4A3372EBDC9C484AA8503A96CD14B858        NaN       False
# 11377  5/27/20 15:53  734CC11FE5EC4290A623F16482B387FF        NaN        True
# 13726  11/1/20 16:00  7AD030340F434EECA5B4FC28034E1113        NaN       False
#
#        is_video  video_duration_secs  impressions  likes  shares  replies  \
# 287       False                  NaN          NaN    604       3        3
# 3940       True               28.612          NaN   1495      79       20
# 3943      False                  NaN          NaN   7356     461       70
# 3944      False                  NaN          NaN    344      15        4
# 3945      False                  NaN          NaN     25       0        0
# 3946       True               25.250          NaN   1192     116       13
# 3947      False                  NaN          NaN     34       0        4
# 4018      False                  NaN          NaN     63       0        0
# 4336      False                  NaN          NaN      0       0        0
# 7822      False                  NaN          NaN      0       0        0
# 9040      False                  NaN          NaN    663      27        0
# 9068      False                  NaN          NaN     35       3        0
# 11377     False                  NaN          NaN      0       0        0
# 13726     False                  NaN          NaN      0       0        0
#
#        engagement_rate
# 287                0.0
# 3940               0.0
# 3943               0.0
# 3944               0.0
# 3945               0.0
# 3946               0.0
# 3947               0.0
# 4018               0.0
# 4336               0.0
# 7822               0.0
# 9040               0.0
# 9068               0.0
# 11377              0.0
# 13726              0.0

# %% [markdown]
# # Look into NaNs more
# - for 14 posts, followers and impressions are NaN so probably drop them
# - a-lot of video duration is NaN, probably fine I reckon it's because video = False

# %%
df[df.is_video == False].shape # yeah that's why
# Out:
# (13152, 11)

# %% [markdown]
# # How do videos do vs non-videos?

# %%
df.is_video.value_counts()
# Out:
# False    13152
# True      1989
# Name: is_video, dtype: int64

# %%
df.engagement_rate.hist(by=df.is_video)
# Out:
# array([<AxesSubplot: title={'center': 'False'}>,
#        <AxesSubplot: title={'center': 'True'}>], dtype=object)
